# %%
import pandas as pd
import os

# %% [markdown]
# ### run this cell as administrator

# %%
# powershell -c "mkdir $env:TEMP\AppLog ; Get-AppXPackage -AllUsers | Out-File $env:TEMP\AppLog\AllAppxPackage.csv"

# %%
temp_dir = os.getenv('TEMP')
filepath = temp_dir+"\\AppLog\\AllAppxPackage.csv"
# Out:
# 'C:\\Users\\moham\\AppData\\Local\\Temp\\AppLog\\AllAppxPackage.csv'

# %% [markdown]
# ### Input data

# %%
with open(filepath, 'r', encoding='utf-16') as file:
    data = file.read()
    # Split the data into lines
    lines = data.strip().split('\n')
    
    # Create a list to store the cleaned-up data
    cleaned_data = []
    data_dict = {}
    
    # Process each line
    for line in lines:
        # Remove leading/trailing whitespace
        line = line.strip()
    
        # Check if the line contains a colon (:)
        if ':' in line:
            key, value = line.split(':', 1)
          
            # Strip leading/trailing whitespace from both key and value
            key = key.strip()
            value = value.strip()
            
            # Add the cleaned-up data to the list
            
            data_dict[key] = value
            # check if the header is Status the last one 
            if (key == "Status"):
                cleaned_data.append(data_dict)
                data_dict = {}

# %% [markdown]
# ### Create a DataFrame from the cleaned data

# %%
df = pd.DataFrame(cleaned_data)
df.head()
# Out:
#                                  Name  \
# 0               Microsoft.UI.Xaml.2.0
# 1             Microsoft.VCLibs.140.00
# 2  Microsoft.NET.Native.Framework.2.2
# 3          Microsoft.Advertising.Xaml
# 4                    Microsoft.Wallet
#
#                                            Publisher Architecture ResourceId  \
# 0  CN=Microsoft Corporation, O=Microsoft Corporat...          X64
# 1  CN=Microsoft Corporation, O=Microsoft Corporat...          X64
# 2  CN=Microsoft Corporation, O=Microsoft Corporat...          X64
# 3  CN=Microsoft Corporation, O=Microsoft Corporat...          X64
# 4  CN=Microsoft Corporation, O=Microsoft Corporat...          X64
#
#           Version                                    PackageFullName  \
# 0  2.1810.18004.0  Microsoft.UI.Xaml.2.0_2.1810.18004.0_x64__8wek...
# 1    14.0.27323.0  Microsoft.VCLibs.140.00_14.0.27323.0_x64__8wek...
# 2     2.2.27405.0  Microsoft.NET.Native.Framework.2.2_2.2.27405.0...
# 3     10.1808.3.0  Microsoft.Advertising.Xaml_10.1808.3.0_x64__8w...
# 4     2.4.18324.0    Microsoft.Wallet_2.4.18324.0_x64__8wekyb3d8bbwe
#
#                                      InstallLocation IsFramework  \
# 0  C:\Program Files\WindowsApps\Microsoft.UI.Xaml...        True
# 1  C:\Program Files\WindowsApps\Microsoft.VCLibs....        True
# 2  C:\Program Files\WindowsApps\Microsoft.NET.Nat...        True
# 3  C:\Program Files\WindowsApps\Microsoft.Adverti...        True
# 4  C:\Program Files\WindowsApps\Microsoft.Wallet_...       False
#
#                                   PackageFamilyName    PublisherId  \
# 0               Microsoft.UI.Xaml.2.0_8wekyb3d8bbwe  8wekyb3d8bbwe
# 1             Microsoft.VCLibs.140.00_8wekyb3d8bbwe  8wekyb3d8bbwe
# 2  Microsoft.NET.Native.Framework.2.2_8wekyb3d8bbwe  8wekyb3d8bbwe
# 3          Microsoft.Advertising.Xaml_8wekyb3d8bbwe  8wekyb3d8bbwe
# 4                    Microsoft.Wallet_8wekyb3d8bbwe  8wekyb3d8bbwe
#
#                               PackageUserInformation IsResourcePackage  \
# 0  {S-1-5-21-1428617228-3619789452-947911753-1001...             False
# 1  {S-1-5-21-1428617228-3619789452-947911753-1001...             False
# 2                      {S-1-5-18 [S-1-5-18]: Staged}             False
# 3  {S-1-5-21-1428617228-3619789452-947911753-1001...             False
# 4  {S-1-5-21-1428617228-3619789452-947911753-1002...             False
#
#   IsBundle IsDevelopmentMode NonRemovable IsPartiallyStaged SignatureKind  \
# 0    False             False        False             False         Store
# 1    False             False        False             False         Store
# 2    False             False        False             False         Store
# 3    False             False        False             False         Store
# 4    False             False        False             False         Store
#
#             Status                                       Dependencies
# 0               Ok                                                NaN
# 1               Ok                                                NaN
# 2               Ok                                                NaN
# 3               Ok                                                NaN
# 4  DependencyIssue  {Microsoft.VCLibs.140.00_14.0.33519.0_x64__8we...

# %%
df.to_csv("./output.csv")
